# %%
import pandas as pd  #data collected from Kaggle and trim down for faster processing
import numpy as np
df = pd.read_csv('data.csv')
print("--- First 5 Rows of the data set---")
print(df.head())
# Out:
# --- First 5 Rows of the data set---
#    vibration  temperature   flow_rate   pressure  power_consumption  \
# 0   5.496714    65.152973  378.092036   7.200357           6.517713
# 1   4.861736    54.223226  295.288584  11.095646           4.925951
# 2  13.535443    73.168231  233.523220   9.758475           6.338338
# 3   6.523030    56.903808  230.568093   9.433472           5.257520
# 4   4.765847    58.362986  282.867461  11.535138           4.968129
#
#   Impeller Type
# 0         Open
# 1         Open
# 2         Open
# 3         Open
# 4         Open

# %%
print("\n--- Dataset Information ---")
df.info()
# Out:
# --- Dataset Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vibration          184 non-null    float64
#  1   temperature        181 non-null    float64
#  2   flow_rate          181 non-null    float64
#  3   pressure           184 non-null    float64
#  4   power_consumption  184 non-null    float64
#  5   Impeller Type      181 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 8.8+ KB

# %%
print("\n--- Descriptive Statistics ---")
print(df.describe())
# Out:
# --- Descriptive Statistics ---
#         vibration  temperature   flow_rate    pressure  power_consumption
# count  184.000000   181.000000  181.000000  184.000000         184.000000
# mean     5.463498    61.254376  299.822278    9.886852           5.066073
# std      2.479768    10.563377   50.155388    1.792022           0.636613
# min      2.380255    41.863962  167.120773    5.449225           3.608067
# 25%      4.387440    56.267248  269.031865    8.761776           4.712402
# 50%      5.068046    60.028898  301.732858    9.871095           5.052202
# 75%      5.741833    64.706614  330.780715   11.102944           5.356050
# max     19.062702   150.000000  459.783275   14.198375           8.427156

# %%
print("\n--- Missing Values Count ---")
print(df.isnull().sum())
# Out:
# --- Missing Values Count ---
# vibration            0
# temperature          3
# flow_rate            3
# pressure             0
# power_consumption    0
# Impeller Type        3
# dtype: int64

# %%
df.dtypes
# Out:
# vibration            float64
# temperature          float64
# flow_rate            float64
# pressure             float64
# power_consumption    float64
# Impeller Type         object
# dtype: object

# %%
df['flow_rate'].median()
# Out:
# 301.7328579

# %%
df['flow_rate'].median()

df['flow_rate']=df['flow_rate'].fillna(df['flow_rate'].median())

# %%
print("\n--- Missing Values Count ---") #checking whether flowrate 
print(df.isnull().sum())
# Out:
# --- Missing Values Count ---
# vibration            0
# temperature          3
# flow_rate            0
# pressure             0
# power_consumption    0
# Impeller Type        3
# dtype: int64

# %%
df['temperature'].median()  
df['temperature']=df['temperature'].fillna(df['temperature'].median())

# %%
df['Impeller Type'].mode()  
df['Impeller Type']=df['Impeller Type'].fillna(df['Impeller Type'].mode()[0])

# %%
print("\n--- Missing Values Count ---") #checking whether flowrate 
print(df.isnull().sum())
# Out:
# --- Missing Values Count ---
# vibration            0
# temperature          0
# flow_rate            0
# pressure             0
# power_consumption    0
# Impeller Type        0
# temperture           0
# dtype: int64

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
# Display first few rows
print("Original Dataset:")
print(df.head())

# for selection of numerical columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Loop through each numerical column and apply IQR
for col in numeric_cols:
    
    # Calculate Q1 and Q3
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(f"\nColumn: {col}")
    print("Lower Bound:", lower_bound)
    print("Upper Bound:", upper_bound)
    print("Number of Outliers:", outliers.shape[0])

# Remove outliers using IQR
for col in numeric_cols:
    
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print("\nDataset after removing outliers:")
print(df.shape)

# Save cleaned dataset
#df.to_csv("cleaned_data.csv", index=False)
# Out:
# Original Dataset:
#    vibration  temperature   flow_rate   pressure  power_consumption  \
# 0   5.496714    65.152973  378.092036   7.200357           6.517713
# 1   4.861736    54.223226  295.288584  11.095646           4.925951
# 2  13.535443    73.168231  233.523220   9.758475           6.338338
# 3   6.523030    56.903808  230.568093   9.433472           5.257520
# 4   4.765847    58.362986  282.867461  11.535138           4.968129
#
#   Impeller Type
# 0         Open
# 1         Open
# 2         Open
# 3         Open
# 4         Open
#
# Column: vibration
# Lower Bound: 2.355850465750001
# Upper Bound: 7.7734228297499985
# Number of Outliers: 8
#
# Column: temperature
# Lower Bound: 43.76795684875
# Upper Bound: 77.22826319875
# Number of Outliers: 4
#
# Column: flow_rate
# Lower Bound: 178.0353626625
# Upper Bound: 420.7199525625
# Number of Outliers: 5
#
# Column: pressure
# Lower Bound: 5.2500230425000005
# Upper Bound: 14.614697086499998
# Number of Outliers: 0
#
# Column: power_consumption
# Lower Bound: 3.746931749750001
# Upper Bound: 6.321520379749998
# Number of Outliers: 7
#
# Dataset after removing outliers:
# (165, 6)

# %%
#create two new feature hydraulic power and efficiency for better data prediction
df['hydraulic_power'] = (df['pressure'] * df['flow_rate']) / 1714
print(df.head())

# %%
df['Efficency'] = (df['hydraulic_power'] / df['power_consumption'])*100
print(df.head())
# Out:
#    vibration  temperature   flow_rate   pressure  power_consumption  \
# 1   4.861736    54.223226  295.288584  11.095646           4.925951
# 3   6.523030    56.903808  230.568093   9.433472           5.257520
# 4   4.765847    58.362986  282.867461  11.535138           4.968129
# 5   4.765863    60.238021  220.974011   9.130663           5.078663
# 6   6.579213    59.402545  329.357403  10.915466           5.076175
#
#   Impeller Type  hydraulic_power  Efficency
# 1         Open          1.911562  38.805952
# 3         Open          1.268995  24.136766
# 4         Open          1.903685  38.317934
# 5         Open          1.177152  23.178390
# 6         Open          2.097485  41.320188

# %%
#saved all the data processing in seperate csv file to avoid any change in default csv file
df.to_csv("cleaned_data.csv", index=False)
